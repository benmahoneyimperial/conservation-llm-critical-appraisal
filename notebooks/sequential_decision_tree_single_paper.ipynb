# %%
# Setup and imports.
import json
import os
import sys
from pathlib import Path

repo_root = Path.cwd().resolve()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
sys.path.append(str(repo_root))

from sequential_decision_tree.evaluator import run_all_trees

# %%
# Choose and load one paper.
PAPER_FILENAME = os.getenv("PAPER_FILENAME", "2.md")
paper_path = repo_root / "data" / "sample_papers" / "sample_papers_md" / PAPER_FILENAME

with open(paper_path, "r", encoding="utf-8") as f:
    paper_text = f.read()

print(f"Loaded {paper_path.name}")
# Out:
# Loaded 2.md

# %%
# Load guidance text.
guidance_path = repo_root / "data" / "guidance_intro_md" / "guidance_intro.md"
guidance_text = None
if guidance_path.exists():
    with open(guidance_path, "r", encoding="utf-8") as f:
        guidance_text = f.read()

print(f"Guidance loaded: {guidance_text is not None}")
# Out:
# Guidance loaded: True

# %%
# Run sequential decision trees on the paper.
results = run_all_trees(
    paper_text=paper_text,
    guidance_text=guidance_text,
    verbose=True,
 )

print("Finished.")
# Out:
# --- Running Tree 1 ---
#
# Node: q_1_1
# Answer: seemingly yes
#
# Node: q_1_2
# Answer: seemingly no
#
# Node: q_1_3
# Answer: no
#
# Final Result: HIGH RISK: Confounding not properly addressed.
#
# --- Running Tree 2 ---
#
# Node: q_2_1
# Answer: unclear
#
# Node: q_2_2_b
# Answer: no
#
# Node: q_2_3_b
# Answer: unclear
#
# Node: q_2_4
# Answer: seemingly no
#
# Node: q_2_5
# Answer: seemingly no
#
# Final Result: MEDIUM RISK
#
# --- Running Tree 3 ---
#
# Node: start
# Answer: yes
#
# Final Result: NOT APPLICABLE: This tree is only for observational studies.
#
# --- Running Tree 4 ---
#
# Node: start
# Answer: seemingly yes
#
# Node: q_4_1
# Answer: seemingly no
#
# Node: q_4_2
# Answer: seemingly yes
#
# Node: q_4_3
# Answer: seemingly yes
#
# Node: q_4_4_c
# Answer: unclear
#
# Node: q_4_5_b
# Answer: seemingly no
#
# Final Result: HIGH
#
# --- Running Tree 5 ---
#
# Node: q_5_1
# Answer: seemingly yes
#
# Node: q_5_2_b
# Answer: seemingly yes
#
# Node: q_5_3_b
# Answer: yes
#
# Final Result: MEDIUM RISK
#
# --- Running Tree 6 ---
#
# Node: q_6_1
# Answer: seemingly no
#
# Node: q_6_2_left
# Answer: seemingly yes
#
# Node: q_6_3_middle
# Answer: seemingly yes
#
# Final Result: HIGH
#
# --- Running Tree 7 ---
#
# Node: start
# Answer: yes
#
# Node: q_7_1_inf
# Answer: seemingly yes
#
# Node: q_7_2_inf_m
# Answer: seemingly no
#
# Node: q_7_3_inf_m
# Answer: seemingly no
#
# Node: q_7_4_inf_m
# Answer: no
#
# Final Result: MEDIUM RISK
#
# --- Overall Bias Risk: HIGH RISK ---
# Finished.

# %%
# Save and preview results.
output_dir = repo_root / "output" / "sequential_decision_tree_single_paper"
output_dir.mkdir(parents=True, exist_ok=True)
output_path = output_dir / f"{paper_path.stem}.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print(f"Saved: {output_path}")
print(json.dumps(results, indent=2)[:2000])
# Out:
# Saved: /home/user/Thesis/conservation-llm-critical-appraisal/output/sequential_decision_tree_single_paper/2.json
# {
#   "1": {
#     "result": "HIGH RISK: Confounding not properly addressed.",
#     "path": [
#       {
#         "node": "q_1_1",
#         "question": "1.1. Is it possible for the impact of the exposure or the effectiveness of the intervention to be confounded in this study?",
#         "answer": "seemingly yes",
#         "full_response": "Evidence Extraction:\nThe methods section describes that seed rain was related to the abundance of mature plants (sources of seeds), with a statement that \"cause and effect might possibly go both ways in these relationships,\" indicating potential issues with causal attribution. Specifically, the text states: \"Seed rain of R. cathartica was related to seedling density, suggesting that high seed rain might lead to high seedling densities. However, seed rain of R. cathartica was not related to sapling density... Differences in distribution between seedlings and saplings of the invasive Prunus serotina in Belgium may have been related to differential response to light,\" implying possible post-dispersal mortality effects and that the observed relationships could be bi-directional or influenced by other variables. Moreover, the discussion notes: \"cause and effect might possibly go both ways in these relationships, with areas of intense seed rain leading to large adult populations or areas with many adult plants causing high seed rain,\" directly indicating potential confounding.\n\nReasoning:\nThe key point here is whether the study design allows for confounding of the effect of seed source density (mature plants) on seed rain, which is being studied as an effect of seed dispersal in different habitats. The authors themselves acknowledge that the observed relationship between seed rain and plant abundance could be bi-directional \u2014 either high seed rain causes high plant density, or high plant density leads to more seed rain, which is a classic case of potential confounding or reverse causality.\n\nFurthermore, the absence of measures to c
